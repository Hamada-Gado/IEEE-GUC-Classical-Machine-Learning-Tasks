# %% [markdown]
# #IEEE Recruitment Task 🔥🔥🔥

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1JD8-6nEYHUws3O9meoXal7irS9d0z7b8)

# %% [markdown]
# ##Note: You are allowed and encouraged to search for answers to any of the following questions before attempting to answer!

# %% [markdown]
# #1. Theoretical Questions 🤔

# %% [markdown]
# *   Why use Numpy instead of implementing mathematical operations on Python lists?
# *   What are the first steps when exploring a new dataset and how to do them? What does EDA stand for?
# *   What are the most common libraries for data visualization in Python?

# %% [markdown]
# Write your answers below:

# %% [markdown]
# * Numpy array uses much less memory than python lists. Access in reading and writing items is also faster with NumPy. Also alot of it has alot of methods, you get a lot of vector and matrix operations for free.
# * 1st Understand the source make sure you understand the format of a dataset, and what problem am I trying to solve? 2nd Basic dimensions know the dimensions of your dataset. Example number of columns & rows, number of variables etc. 3rd Data type Best practices if understanding and changing the format of data type of each column for easy and clean analysis. 4th Clean the data example you need to deal with null values and empty cells. 5th Visualize it makes your findings presentable and has a better audience reach. EDA stands for Electronic Design Automation.
# * TensorFlow, NumPy, Pandas, Matplotlib, Seaborn, Plotly, Bokeh, ggplot

# %% [markdown]
# #2. Python Skills 🐍

# %% [markdown]
# Retype the following string in a third way using python's f-string feature

# %%
model_name = "SVM"
metric = "F1 score"
score = 0.8
fold_no = 3
total_folds = 5

"Model name: %s. Fold number %s out of %s folds. %s: %s." % (model_name, fold_no, total_folds, metric, score)
"Model name: {}. Fold number {} out of {} folds. {}: {}.".format(model_name, fold_no, total_folds, metric, score)
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
f"Model name: {model_name} Fold number {fold_no} out of {total_folds} folds. {metric}: {score}."
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Create a string by concatenating strings in the following list

# %%
['This', 'is', 'one', 'string', '.']
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
" ".join(['This', 'is', 'one', 'string', '.'])
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Write the following loop in a more pythonic way using enumerate

# %%
items = ["1st", "2nd", '3rd']
for i in range(len(items)):
  print(i, items[i])
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
for index, item in enumerate(items):
  print(index, item)
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #3. Numpy 🔢

# %%
import numpy as np
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Given the following list, use numpy to get its mean.

# %%
arr = [2,5,7,11,13,17,23,31,37,41,43,47]
np.mean(arr)
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Convert the list into a numpy array

# %%
arr = [2,5,7,11,13,17,23,31,37,41,43,47]
arr = np.array(arr)
print(arr)
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Create an array of all zeros using numpy of shape (5,12)

# %%
print(np.zeros((5,12), dtype= int))
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Create an array of integers from 0 to 255 inclusive

# %%
print(np.arange(stop=256))
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #4. Pandas 🐼

# %%
import pandas as pd
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Run the following cell to download the dataset

# %%
# !gdown https://drive.google.com/uc?id=1OtsvAXz0oePY4-bRmMVDOOQjaSvhyifK -O census_data.csv
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# Given the following dataset about census data:

# %%
df = pd.read_csv('census_data.csv')
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 1. What are the data types of each column?

# %%
df.dtypes
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 2. Describe a summary of the main dataset statistics using a pandas function

# %%
df.describe()
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 3. How many unique occupations are included? What are their counts?

# %%
unique_occupations = df['occupation'].unique()
print(f'number of unique occupations {len(unique_occupations)}')
print()
pd.value_counts(df.occupation)
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 4. How many have a Bachelor's degree from the United States and an income of  <=50K?

# %%
((df['nativeCountry'] == 'United-States') & (df['income'] == '<=50K')).sum()
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 5. How many NaN values does each column contain?

# %%
df.isnull().sum()
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #5. Matplotlib 🖌

# %%
import matplotlib.pyplot as plt
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 1. Draw a Histogram for education categories

# %%
fig, ax = plt.subplots(figsize =(20, 5))
plt.hist(df['education'].values)
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 2. Draw a Box plot for ages

# %%
fig, ax = plt.subplots(figsize =(10, 5))
plt.boxplot(df['age'].values, labels=['ages'])
# Out:
# Running cells with 'Python 3.10.3 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python/Python310/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #You've reached the end. Good luck and don't give up! 🔥🔥🔥
